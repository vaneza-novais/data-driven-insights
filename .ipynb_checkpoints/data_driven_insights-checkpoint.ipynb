# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Exibir o tipo de cada coluna do df
def colunas_df(df):
    for col in df.columns:
        tipo = df[col].dtype
        print(col, ", tipo: ", tipo)

#Definir se o estudante foi aprovado informando o df e dias de curso e nota minima
def student_approved(df, days, grade):
    absences = df["absences"] < days * 0.25 #quantidade de faltas deve ser inferior a 25%
    G3 = df["G3"] >= grade

    df["status"] = np.where(absences & G3,
                            "approved",
                            "inapproved")

# %%
df_student_mat = pd.read_csv('student-mat.csv', sep= ";")
print(df_student_mat.head())
print(df_student_mat.columns)
print(df_student_mat.describe())
print(df_student_mat.dtypes)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df_student_por = pd.read_csv('student-por.csv', sep= ";")
print(df_student_por.head())
print(df_student_por.columns)
print(df_student_por.describe())
print(df_student_por.dtypes)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# ### Insight:
#
# Foi observado que essa base apresenta dados sobre determinada disciplina, quanto as duas escolas e informações do aluno que a cursam.
#
# Os tipos de dados são variados ente categóricos e numéricos e aparentemente as colunas de ambos dataframes são idênticas.

# %%
colunas_df(df_student_mat)
# Out:
# school , tipo:  object
# sex , tipo:  object
# age , tipo:  int64
# address , tipo:  object
# famsize , tipo:  object
# Pstatus , tipo:  object
# Medu , tipo:  int64
# Fedu , tipo:  int64
# Mjob , tipo:  object
# Fjob , tipo:  object
# reason , tipo:  object
# guardian , tipo:  object
# traveltime , tipo:  int64
# studytime , tipo:  int64
# failures , tipo:  int64
# schoolsup , tipo:  object
# famsup , tipo:  object
# paid , tipo:  object
# activities , tipo:  object
# nursery , tipo:  object
# higher , tipo:  object
# internet , tipo:  object
# romantic , tipo:  object
# famrel , tipo:  int64
# freetime , tipo:  int64
# goout , tipo:  int64
# Dalc , tipo:  int64
# Walc , tipo:  int64
# health , tipo:  int64
# absences , tipo:  int64
# G1 , tipo:  int64
# G2 , tipo:  int64
# G3 , tipo:  int64

# %%
colunas_df(df_student_por)
# Out:
# school , tipo:  object
# sex , tipo:  object
# age , tipo:  int64
# address , tipo:  object
# famsize , tipo:  object
# Pstatus , tipo:  object
# Medu , tipo:  int64
# Fedu , tipo:  int64
# Mjob , tipo:  object
# Fjob , tipo:  object
# reason , tipo:  object
# guardian , tipo:  object
# traveltime , tipo:  int64
# studytime , tipo:  int64
# failures , tipo:  int64
# schoolsup , tipo:  object
# famsup , tipo:  object
# paid , tipo:  object
# activities , tipo:  object
# nursery , tipo:  object
# higher , tipo:  object
# internet , tipo:  object
# romantic , tipo:  object
# famrel , tipo:  int64
# freetime , tipo:  int64
# goout , tipo:  int64
# Dalc , tipo:  int64
# Walc , tipo:  int64
# health , tipo:  int64
# absences , tipo:  int64
# G1 , tipo:  int64
# G2 , tipo:  int64
# G3 , tipo:  int64

# %%
#verificar se ambos df são iguais para unificar
if colunas_df(df_student_por) == colunas_df(df_student_mat):
    print("Colunas iguais")
else:
    print("Colunas diferentes")
# Out:
# school , tipo:  object
# sex , tipo:  object
# age , tipo:  int64
# address , tipo:  object
# famsize , tipo:  object
# Pstatus , tipo:  object
# Medu , tipo:  int64
# Fedu , tipo:  int64
# Mjob , tipo:  object
# Fjob , tipo:  object
# reason , tipo:  object
# guardian , tipo:  object
# traveltime , tipo:  int64
# studytime , tipo:  int64
# failures , tipo:  int64
# schoolsup , tipo:  object
# famsup , tipo:  object
# paid , tipo:  object
# activities , tipo:  object
# nursery , tipo:  object
# higher , tipo:  object
# internet , tipo:  object
# romantic , tipo:  object
# famrel , tipo:  int64
# freetime , tipo:  int64
# goout , tipo:  int64
# Dalc , tipo:  int64
# Walc , tipo:  int64
# health , tipo:  int64
# absences , tipo:  int64
# G1 , tipo:  int64
# G2 , tipo:  int64
# G3 , tipo:  int64
# school , tipo:  object
# sex , tipo:  object
# age , tipo:  int64
# address , tipo:  object
# famsize , tipo:  object
# Pstatus , tipo:  object
# Medu , tipo:  int64
# Fedu , tipo:  int64
# Mjob , tipo:  object
# Fjob , tipo:  object
# reason , tipo:  object
# guardian , tipo:  object
# traveltime , tipo:  int64
# studytime , tipo:  int64
# failures , tipo:  int64
# schoolsup , tipo:  object
# famsup , tipo:  object
# paid , tipo:  object
# activities , tipo:  object
# nursery , tipo:  object
# higher , tipo:  object
# internet , tipo:  object
# romantic , tipo:  object
# famrel , tipo:  int64
# freetime , tipo:  int64
# goout , tipo:  int64
# Dalc , tipo:  int64
# Walc , tipo:  int64
# health , tipo:  int64
# absences , tipo:  int64
# G1 , tipo:  int64
# G2 , tipo:  int64
# G3 , tipo:  int64
# Colunas iguais

# %% [markdown]
# Como a condição retornou "Colunas iguais" então podemos unificar e analisar as duas informações juntos

# %%
#Definir uma nova coluna para distiguir qual a disciplina em questão
df_student_por["language"] = "Portuguese"
df_student_mat["language"] = "Mathematics"

#Unificar as bases
df_student = pd.concat([df_student_por, df_student_mat], ignore_index=True)
print(df_student.head())
print(df_student.describe())
print(df_student.dtypes)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3    language
# 0        3     4     1     1       3        4   0  11  11  Portuguese
# 1        3     3     1     1       3        2   9  11  11  Portuguese
# 2        3     2     2     3       3        6  12  13  12  Portuguese
# 3        2     2     1     1       5        0  14  14  14  Portuguese
# 4        3     2     1     2       5        0  11  13  13  Portuguese
#
# [5 rows x 34 columns]
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       0.000000     4.000000     3.000000     2.000000     1.000000
# 50%       0.000000     4.000000     3.000000     3.000000     1.000000
# 75%       0.000000     5.000000     4.000000     4.000000     2.000000
# max       3.000000     5.000000     5.000000     5.000000     5.000000
#
#               Walc       health     absences           G1           G2  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      2.284483     3.543103     4.434866    11.213602    11.246169
# std       1.285105     1.424703     6.210017     2.983394     3.285071
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%       1.000000     3.000000     0.000000     9.000000     9.000000
# 50%       2.000000     4.000000     2.000000    11.000000    11.000000
# 75%       3.000000     5.000000     6.000000    13.000000    13.000000
# max       5.000000     5.000000    75.000000    19.000000    19.000000
#
#                 G3
# count  1044.000000
# mean     11.341954
# std       3.864796
# min       0.000000
# 25%      10.000000
# 50%      11.000000
# 75%      14.000000
# max      20.000000
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# language      object
# dtype: object

# %%
df_student.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'language'],
#       dtype='object')

# %%
# Lista
### Entendendo a profissão das mães
Mjob = list(df_student["Mjob"])

result = []

for i in Mjob:
    if i not in result:
        result.append(i)
    else:
        pass

print(result)
# Out:
# ['at_home', 'health', 'other', 'services', 'teacher']

# %%
# Dicionario
### Enteder se há relação entre o tempo de estudo e tempode locomoção até a escola
dic1 = dict(zip(df_student["studytime"], df_student["traveltime"]))
print(dic1)

### Enteder se há relação entre o tempo de estudo e tempo de livre
dic2 = dict(zip(df_student["studytime"], df_student["freetime"]))
print(dic2)
# Out:
# {2: 1, 3: 1, 1: 1, 4: 1}
# {2: 5, 3: 4, 1: 2, 4: 3}

# %% [markdown]
# ### Insight
#
# Pela lista entende-se que as profissões das mães são resumidas em áreas de atuação, como: em casa, saúde, geral, professora entre outros.
# Pelo dicionário, fica claro que todos gastam mesmo tempo de locomoção até a escola e que maior tempo de estudo não implica necessariamente em menor tempo livre.

# %%
#Vamos considerar que teve 200 dias de aulas durante o ano todo, e nota minima é 6.0 , logo:
student_approved(df_student, 200, 6)

df_student
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   M   20       U     LE3       A     2     2  services  services
# 1040     MS   M   17       U     LE3       T     3     1  services  services
# 1041     MS   M   21       R     GT3       T     1     1     other     other
# 1042     MS   M   18       R     LE3       T     3     2  services     other
# 1043     MS   M   19       U     LE3       T     1     1     other   at_home
#
#       ... goout Dalc  Walc  health  absences  G1  G2  G3     language  \
# 0     ...     4    1     1       3         4   0  11  11   Portuguese
# 1     ...     3    1     1       3         2   9  11  11   Portuguese
# 2     ...     2    2     3       3         6  12  13  12   Portuguese
# 3     ...     2    1     1       5         0  14  14  14   Portuguese
# 4     ...     2    1     2       5         0  11  13  13   Portuguese
# ...   ...   ...  ...   ...     ...       ...  ..  ..  ..          ...
# 1039  ...     4    4     5       4        11   9   9   9  Mathematics
# 1040  ...     5    3     4       2         3  14  16  16  Mathematics
# 1041  ...     3    3     3       3         3  10   8   7  Mathematics
# 1042  ...     1    3     4       5         0  11  12  10  Mathematics
# 1043  ...     3    3     3       5         5   8   9   9  Mathematics
#
#         status
# 0     approved
# 1     approved
# 2     approved
# 3     approved
# 4     approved
# ...        ...
# 1039  approved
# 1040  approved
# 1041  approved
# 1042  approved
# 1043  approved
#
# [1044 rows x 35 columns]

# %%
aprovados = df_student[df_student["status"] == "approved"].shape[0]
reprovados = df_student[df_student["status"] == "repproved"].shape[0]

if reprovados == 0:
    print(f"Todos os alunos foram aprovados.")
else:
    print(f"Cerca de {aprovados} foram aprovados e os demais, {reprovados}, foram reprovados.")
# Out:
# Todos os alunos foram aprovados.

# %%
#Obter a média de faltas
array1 = np.array(df_student["absences"])

print("Média de faltas:", array1.mean().astype(int))

#Entender a classificacao de saude em relação ao consumo de alcool durante dias úteis
df_health_walc = df_student.groupby("health")["Dalc"].mean()
df_health_walc
# Out:
# Média de faltas: 4
# health
# 1    1.459854
# 2    1.390244
# 3    1.409302
# 4    1.522989
# 5    1.572152
# Name: Dalc, dtype: float64

# %%
#Vamos entender qual escola obtem maior nota final, para o primeiro e segundo periodo
df_school_grade = df_student.groupby("school")["G3"].mean()
df_school_grade
# Out:
# school
# GP    11.633420
# MS    10.514706
# Name: G3, dtype: float64

# %% [markdown]
# ### Insight
# Entende-se que a média de faltas é 4, além de que, contraditoriamente ao esperado, o consumo maior de alcool representa uma maior qualidade de saúde exceto para o nível 3. Essa ultima parte será validada pelos graficos.

# %%
df_health_walc.plot(kind="line", color="pink")
plt.title('Nível de saúde x Consumo de álcool em dias úteis')
plt.xlabel("Nível de saúde")
plt.ylabel("Consumo médio de álcool")

plt.show()

# %% [markdown]
# ### Insight
# O gráfico em questão reforçou o resultado obtido pro agrupamento, ou seja, o a média de consumo em dias úteis é proporcional ao nível de saude, exceto para o nível 3.

# %%
#Vamos comparar se alunos que cursam matemática ou português apresentam maior tempo de estudo entre si
df_math_studytime = df_student.groupby("language")["studytime"].mean()
df_math_studytime
# Out:
# language
# Mathematics    2.035443
# Portuguese     1.930663
# Name: studytime, dtype: float64

# %% [markdown]
# ### Insight
# Ou seja, alunos de matemática apresenta um tempo maior de estudo,

# %%
df_school_grade.plot(kind='bar', color="#ADD8E6")
plt.title('Nota final média para cada escola')
plt.xlabel("Escola")
plt.ylabel("Nota final")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Insight
# Logo, conclui-se que a escola Gabriel Pereira (GP) apresenta uma nota final maior que a Mousinho da Silveira (MS)

# %%
df_student['G3'].dtypes
# Out:
# dtype('int64')

# %%
#Vamos entender a relação entre as notas e idades
colors = df_student['sex'].map({'F': 'red', 'M': 'blue'})

plt.scatter(df_student['G3'], df_student['age'], c=colors)
plt.title('Nota final x Idade')
plt.ylabel("Idade")
plt.xlabel("Nota final")
# Out:
# Text(0.5, 0, 'Nota final')
